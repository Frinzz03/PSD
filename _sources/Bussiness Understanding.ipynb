# %% [markdown]
# # **Business Understanding : Dataset Iris**
# Business Understanding adalah fase awal dan terpenting dalam proyek data science. Di sini, kita fokus pada pemahaman mendalam terhadap masalah yang ingin kita selesaikan, bukan hanya pada data itu sendiri. Tujuannya adalah memastikan bahwa proyek kita relevan, memiliki nilai bisnis, dan dapat diukur keberhasilannya.

# %% [markdown]
# ## **1. Menentukan Tujuan Bisnis** 🎯
# Tujuan bisnis harus spesifik, terukur, dan berorientasi pada hasil. Dalam kasus data Iris, tujuannya cukup jelas: membangun sebuah model machine learning yang dapat memprediksi spesies bunga Iris berdasarkan empat fitur fisiknya.
#
# Ini adalah masalah klasifikasi, di mana kita akan mengelompokkan bunga ke dalam salah satu dari tiga spesies: Iris-setosa, Iris-versicolor, atau Iris-virginica.

# %% [markdown]
# ## **2. Membuat Rencana Proyek** 🗺️
# Setelah tujuan ditetapkan, kita menyusun rencana kerja sebagai peta jalan. Rencana ini akan memandu kita dari awal hingga akhir proyek. Berikut adalah rencana sederhana untuk proyek ini:
#
# - Pengumpulan Data: Data yang digunakan adalah dataset iris (data iris.csv).
#
# - Eksplorasi Data Awal: Memeriksa struktur data, tipe data, dan statistiknya.
#
# - Persiapan Data: Menangani missing values (jika ada) dan memastikan data siap untuk pemodelan.
#
# - Pemodelan: Melatih model machine learning.
#
# - Evaluasi Model: Menguji performa model menggunakan metrik seperti akurasi.

# %% [markdown]
# ## **3. Menilai Situasi dan Kondisi** ✅
# Ini adalah tahap untuk mengevaluasi kualitas data dan sumber daya yang ada. Dengan data Iris, kita perlu memastikan bahwa data bersih dan cocok untuk tujuan kita.
#
# Mari kita periksa informasi dasar data:
#
# Apakah ada nilai yang hilang (missing values)?
#
# Apakah tipe data sudah sesuai?
#
# Bagaimana sebaran data untuk setiap spesies?

# %% [markdown]
# **Hasil Penilaian:**
#
# df.info() menunjukkan bahwa tidak ada nilai yang hilang (Non-Null Count sama dengan 150 untuk semua kolom), yang berarti data kita bersih.
#
# df['Class'].value_counts() menunjukkan ada 50 entri untuk setiap spesies. Ini adalah dataset yang seimbang, yang ideal
